# %% [markdown]
# ## Calculating Cost Function And Gradient Descent For Linear Regression.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score,mean_squared_error
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('Student_Marks.csv')
df.head()
# Out:
#    number_courses  time_study   Marks
# 0               3       4.508  19.202
# 1               4       0.096   7.734
# 2               4       3.133  13.811
# 3               6       7.909  53.018
# 4               8       7.811  55.299

# %%
x = df['time_study']
y = df['Marks']

# %%
def hypothesis(theta0,theta1,x):
  return theta0 + theta1 * x

# %%
def costFunction(theta0,theta1,x,y):
  m = len(x)
  y_hat = hypothesis(theta0,theta1,x)
  cost = np.sum((y_hat - y)**2) / (2 * m)
  return cost

# For Loop Approach
# sums = 0
# for i in range(m):
#    sums += (hypothesis(theta0,theta1,x[i]) - y[i])**2
# cost = 1/(2*m) * sums

# %%
def computeGradients(theta0,theta1,x,y):
  m = len(x)
  y_hat = hypothesis(theta0,theta1,x)
  dtheta0 = 1/m * np.sum(y_hat-y)
  dtheta1 = 1/m * np.sum((y_hat-y)*x)
  return dtheta0,dtheta1

# For Loop Approach
# dtheta0 = 0
# dtheta1 = 0
# for i in range(m):
#   dtheta0 += (hypothesis(theta0,theta1,x[i]) - y[i])
#   dtheta1 += (hypothesis(theta0,theta1,x[i]) - y[i]) * x[i]
# dtheta0 = (1/m) * dtheta0
# dtheta1 = (1/m) * dtheta1

# %%
def updateParameters(theta0,theta1,dtheta0,dtheta1,alpha):
  theta0 = theta0 - alpha*dtheta0
  theta1 = theta1 - alpha*dtheta1
  return theta0,theta1

# %%
def GradientDescent(theta0,theta1,x,y,alpha,iterations):
  for i in range(iterations):
    if i % 100 == 0:
      print(costFunction(theta0,theta1,x,y))
    dtheta0,dtheta1 = computeGradients(theta0,theta1,x,y)
    theta0,theta1 = updateParameters(theta0,theta1,dtheta0,dtheta1,alpha)
  return theta0,theta1

# %%
theta0,theta1,alpha,iterations = 0,0,0.05,500
theta0,theta1 = GradientDescent(theta0,theta1,x,y,alpha,iterations)
print(f"theta0 = {theta0} and theta1 = {theta1}")
# Out:
# 399.705575385
# 11.39480127449037
# 11.394540313196067
# 11.394517642786004
# 11.394515673346461
# theta0 = 1.223498128651425 and theta1 = 5.688817272001179

# %%
print("R2 Score = ", round(r2_score(y,hypothesis(theta0,theta1,x)),3))
print("Mean Squared Error = ", round(mean_squared_error(y,hypothesis(theta0,theta1,x)),3))
# Out:
# R2 Score =  0.888
# Mean Squared Error =  22.789

# %% [markdown]
# ## Calculating Cost Function And Gradient Descent For Multi-Regression.

# %%
data = pd.read_csv('Student_Marks.csv')
if 'No' in data.columns:
    data.drop('No', axis=1, inplace=True)
data.head()
# Out:
#    number_courses  time_study   Marks
# 0               3       4.508  19.202
# 1               4       0.096   7.734
# 2               4       3.133  13.811
# 3               6       7.909  53.018
# 4               8       7.811  55.299

# %%
Y = data['Marks'].values.reshape(-1, 1)  # Shape (100, 1)

# Ensure X is correctly scaled
scaler = StandardScaler()
X_scaled = scaler.fit_transform(data[['number_courses', 'time_study']])

# %%
theta0 = 0
theta = np.zeros((X_scaled.shape[1], 1))
alpha = 0.01
iterations = 1000

# %%
def hypothesis(theta0,theta,X):
  return theta0 + np.dot(X,theta)

# %%
def costFunction(theta0, theta, X, Y):
    m = len(Y)
    y_hat = hypothesis(theta0, theta, X)
    cost = np.sum((y_hat - Y) ** 2) / (2 * m)
    return cost

# %%
def computeGradients(theta0, theta, X, Y):
    m = len(Y)
    y_hat = hypothesis(theta0, theta, X)

    dtheta0 = (1 / m) * np.sum(y_hat - Y)
    dtheta = (1 / m) * np.dot(X.T, (y_hat - Y))

    return dtheta0, dtheta

# %%
def updateParameters(theta0,theta,dtheta0,dtheta,alpha):
  theta0 = theta0 - alpha*dtheta0
  theta = theta - alpha*dtheta
  return theta0,theta

# %%
def GradientDescent(theta0, theta, X, Y, alpha, iterations):
    for i in range(iterations):
        dtheta0, dtheta = computeGradients(theta0, theta, X, Y)

        # Debugging print statements to check shapes
        print(f"Iteration {i}: theta0 shape = {np.shape(theta0)}, theta shape = {np.shape(theta)}")
        print(f"dtheta0 shape = {np.shape(dtheta0)}, dtheta shape = {np.shape(dtheta)}")

        theta0, theta = updateParameters(theta0, theta, dtheta0, dtheta, alpha)

        if i % 100 == 0:
            print(f"Iteration {i}: Cost = {costFunction(theta0, theta, X, Y)}")

    return theta0, theta

theta0, theta = GradientDescent(theta0, theta, X_scaled, Y, alpha, iterations)
# Out:
# Iteration 0: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 0: Cost = 391.6277034298356
# Iteration 1: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 2: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 3: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 4: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 5: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 6: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 7: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 8: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 9: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 10: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 11: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 12: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 13: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 14: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 15: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 16: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 17: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 18: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 19: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 20: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 21: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 22: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 23: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 24: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 25: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 26: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 27: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 28: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 29: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 30: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 31: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 32: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 33: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 34: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 35: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 36: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 37: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 38: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 39: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 40: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 41: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 42: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 43: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 44: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 45: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 46: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 47: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 48: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 49: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 50: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 51: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 52: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 53: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 54: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 55: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 56: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 57: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 58: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 59: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 60: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 61: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 62: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 63: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 64: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 65: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 66: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 67: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 68: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 69: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 70: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 71: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 72: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 73: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 74: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 75: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 76: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 77: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 78: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 79: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 80: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 81: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 82: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 83: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 84: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 85: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 86: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 87: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 88: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 89: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 90: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 91: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 92: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 93: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 94: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 95: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 96: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 97: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 98: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 99: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 100: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 100: Cost = 55.4485760603202
# Iteration 101: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 102: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 103: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 104: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 105: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 106: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 107: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 108: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 109: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 110: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 111: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 112: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 113: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 114: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 115: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 116: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 117: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 118: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 119: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 120: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 121: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 122: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 123: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 124: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 125: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 126: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 127: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 128: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 129: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 130: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 131: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 132: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 133: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 134: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 135: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 136: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 137: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 138: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 139: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 140: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 141: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 142: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 143: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 144: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 145: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 146: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 147: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 148: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 149: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 150: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 151: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 152: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 153: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 154: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 155: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 156: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 157: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 158: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 159: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 160: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 161: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 162: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 163: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 164: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 165: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 166: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 167: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 168: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 169: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 170: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 171: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 172: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 173: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 174: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 175: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 176: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 177: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 178: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 179: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 180: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 181: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 182: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 183: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 184: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 185: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 186: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 187: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 188: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 189: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 190: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 191: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 192: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 193: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 194: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 195: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 196: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 197: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 198: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 199: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 200: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 200: Cost = 12.610411023009835
# Iteration 201: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 202: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 203: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 204: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 205: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 206: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 207: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 208: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 209: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 210: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 211: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 212: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 213: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 214: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 215: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 216: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 217: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 218: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 219: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 220: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 221: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 222: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 223: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 224: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 225: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 226: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 227: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 228: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 229: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 230: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 231: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 232: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 233: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 234: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 235: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 236: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 237: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 238: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 239: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 240: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 241: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 242: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 243: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 244: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 245: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 246: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 247: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 248: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 249: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 250: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 251: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 252: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 253: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 254: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 255: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 256: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 257: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 258: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 259: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 260: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 261: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 262: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 263: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 264: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 265: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 266: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 267: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 268: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 269: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 270: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 271: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 272: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 273: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 274: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 275: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 276: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 277: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 278: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 279: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 280: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 281: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 282: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 283: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 284: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 285: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 286: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 287: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 288: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 289: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 290: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 291: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 292: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 293: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 294: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 295: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 296: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 297: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 298: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 299: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 300: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 300: Cost = 6.957968969428675
# Iteration 301: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 302: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 303: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 304: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 305: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 306: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 307: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 308: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 309: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 310: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 311: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 312: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 313: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 314: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 315: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 316: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 317: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 318: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 319: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 320: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 321: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 322: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 323: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 324: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 325: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 326: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 327: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 328: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 329: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 330: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 331: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 332: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 333: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 334: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 335: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 336: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 337: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 338: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 339: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 340: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 341: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 342: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 343: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 344: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 345: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 346: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 347: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 348: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 349: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 350: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 351: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 352: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 353: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 354: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 355: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 356: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 357: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 358: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 359: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 360: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 361: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 362: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 363: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 364: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 365: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 366: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 367: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 368: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 369: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 370: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 371: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 372: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 373: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 374: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 375: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 376: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 377: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 378: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 379: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 380: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 381: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 382: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 383: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 384: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 385: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 386: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 387: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 388: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 389: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 390: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 391: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 392: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 393: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 394: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 395: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 396: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 397: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 398: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 399: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 400: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 400: Cost = 6.186472131173094
# Iteration 401: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 402: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 403: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 404: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 405: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 406: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 407: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 408: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 409: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 410: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 411: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 412: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 413: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 414: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 415: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 416: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 417: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 418: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 419: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 420: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 421: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 422: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 423: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 424: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 425: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 426: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 427: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 428: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 429: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 430: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 431: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 432: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 433: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 434: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 435: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 436: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 437: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 438: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 439: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 440: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 441: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 442: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 443: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 444: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 445: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 446: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 447: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 448: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 449: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 450: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 451: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 452: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 453: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 454: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 455: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 456: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 457: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 458: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 459: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 460: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 461: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 462: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 463: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 464: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 465: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 466: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 467: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 468: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 469: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 470: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 471: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 472: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 473: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 474: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 475: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 476: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 477: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 478: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 479: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 480: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 481: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 482: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 483: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 484: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 485: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 486: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 487: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 488: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 489: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 490: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 491: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 492: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 493: theta0 shape = (), theta shape = (2, 1)
# ...
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 836: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 837: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 838: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 839: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 840: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 841: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 842: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 843: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 844: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 845: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 846: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 847: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 848: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 849: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 850: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 851: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 852: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 853: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 854: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 855: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 856: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 857: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 858: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 859: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 860: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 861: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 862: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 863: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 864: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 865: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 866: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 867: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 868: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 869: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 870: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 871: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 872: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 873: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 874: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 875: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 876: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 877: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 878: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 879: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 880: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 881: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 882: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 883: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 884: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 885: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 886: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 887: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 888: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 889: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 890: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 891: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 892: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 893: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 894: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 895: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 896: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 897: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 898: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 899: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 900: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 900: Cost = 6.058495074248157
# Iteration 901: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 902: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 903: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 904: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 905: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 906: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 907: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 908: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 909: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 910: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 911: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 912: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 913: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 914: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 915: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 916: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 917: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 918: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 919: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 920: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 921: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 922: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 923: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 924: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 925: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 926: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 927: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 928: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 929: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 930: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 931: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 932: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 933: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 934: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 935: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 936: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 937: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 938: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 939: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 940: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 941: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 942: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 943: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 944: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 945: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 946: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 947: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 948: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 949: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 950: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 951: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 952: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 953: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 954: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 955: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 956: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 957: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 958: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 959: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 960: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 961: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 962: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 963: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 964: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 965: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 966: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 967: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 968: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 969: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 970: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 971: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 972: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 973: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 974: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 975: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 976: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 977: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 978: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 979: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 980: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 981: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 982: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 983: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 984: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 985: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 986: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 987: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 988: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 989: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 990: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 991: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 992: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 993: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 994: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 995: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 996: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 997: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 998: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)
# Iteration 999: theta0 shape = (), theta shape = (2, 1)
# dtheta0 shape = (), dtheta shape = (2, 1)

# %%
print(f"Optimized theta0 = {theta0}, theta = {theta.flatten()}")
# Out:
# Optimized theta0 = 24.41768995449137, theta = [ 3.33758848 12.74756727]

# %%
print("X shape:", X.shape)
print("theta shape:", theta.shape)
# Out:
# X shape: (100, 1)
# theta shape: (2, 1)

# %%
theta = np.zeros((X.shape[1], 1))  # Shape (features, 1)

# %%
def hypothesis(theta0, theta, X):
    return theta0 + X @ theta

# %%
y_pred = hypothesis(theta0, theta, X)

# Compute Metrics
print(round(r2_score(Y, y_pred), 3))
print(round(mean_squared_error(Y, y_pred), 3))
# Out:
# -0.0
# 203.188
